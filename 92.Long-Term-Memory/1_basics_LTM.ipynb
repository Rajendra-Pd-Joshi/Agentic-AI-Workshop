# %%
from langgraph.store.memory import InMemoryStore

# %%
store = InMemoryStore()

# %%
# create a namespace
namespace = ('user','u1')

# %%
# put method to write
store.put(namespace = namespace,key='details',value={'data':'user name is raju joshi'})
store.put(namespace = ('user','u1'),key='preferences',value={'data':'user prefer the dark theme'})

# %%
# get method to read
store.get(namespace = ('user','u1'),key='preferences')
# Out:
# Item(namespace=['user', 'u1'], key='preferences', value={'data': 'user prefer the dark theme'}, created_at='2026-09-18T08:44:33.746159+00:00', updated_at='2026-09-18T08:44:33.746159+00:00')

# %%
# search method to get the all memory of namespaces
store.search(('user','u1'))
# Out:
# [Item(namespace=['user', 'u1'], key='details', value={'data': 'user name is raju joshi'}, created_at='2026-09-18T08:44:33.746092+00:00', updated_at='2026-09-18T08:44:33.746095+00:00', score=None),
#  Item(namespace=['user', 'u1'], key='preferences', value={'data': 'user prefer the dark theme'}, created_at='2026-09-18T08:44:33.746159+00:00', updated_at='2026-09-18T08:44:33.746159+00:00', score=None)]

# %% [markdown]
# #### but the problem is get needs the key to reterive and search can we used when need all memory but we wan't specific memory and don't have key . memory without key

# %% [markdown]
# ## concept of sementic search

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# create an embedding model
from langchain_openai import OpenAIEmbeddings
model = OpenAIEmbeddings(model = 'text-embedding-3-small')

# %%
# create an memory store with the index to activate the sementic search on the memory
store = InMemoryStore(index= {
    'dims':'30',
    'embed': model
})

# %%
# creating namespace
namespace = ('users', 'raju')

# %%
# put some memory on the namespace
store.put(namespace, "1", {"data": "User prefers concise answers over long explanations"})
store.put(namespace, "2", {"data": "User likes examples in Python"})
store.put(namespace, "3", {"data": "User usually works late at night"})
store.put(namespace, "4", {"data": "User prefers dark mode in applications"})
store.put(namespace, "5", {"data": "User is learning machine learning"})
store.put(namespace, "6", {"data": "User dislikes overly theoretical explanations"})
store.put(namespace, "7", {"data": "User prefers step-by-step reasoning"})
store.put(namespace, "8", {"data": "User is based in India"})
store.put(namespace, "9", {"data": "User likes real-world analogies"})
store.put(namespace, "10", {"data": "User prefers bullet points over paragraphs"})

# %%
# now get the relevent memory using store.search
store.search(namespace,query='what are the user preferances',limit = 3)
# Out:
# NumPy not found in the current Python environment. The InMemoryStore will use a pure Python implementation for vector operations, which may significantly impact performance, especially for large datasets or frequent searches. For optimal speed and efficiency, consider installing NumPy: pip install numpy
# [Item(namespace=['users', 'raju'], key='4', value={'data': 'User prefers dark mode in applications'}, created_at='2026-09-18T08:53:39.775404+00:00', updated_at='2026-09-18T08:53:39.775415+00:00', score=0.4947640784997101),
#  Item(namespace=['users', 'raju'], key='10', value={'data': 'User prefers bullet points over paragraphs'}, created_at='2026-09-18T08:53:42.663557+00:00', updated_at='2026-09-18T08:53:42.663562+00:00', score=0.47982598143063315),
#  Item(namespace=['users', 'raju'], key='1', value={'data': 'User prefers concise answers over long explanations'}, created_at='2026-09-18T08:53:38.272857+00:00', updated_at='2026-09-18T08:53:38.272860+00:00', score=0.4707946807990633)]
